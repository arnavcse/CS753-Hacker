# %%
# !git clone https://github.com/kssteven418/Squeezeformer.git
# Out:
# Cloning into 'Squeezeformer'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 90 (delta 30), reused 61 (delta 12), pack-reused 0
# Receiving objects: 100% (90/90), 196.68 KiB | 1.46 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !pip install -r /content/Squeezeformer/requirements.txt
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
cd /content
# Out:
# /content

# %%
cd Squeezeformer/scripts
# Out:
# /content/Squeezeformer/scripts

# %%
# !bash /content/Squeezeformer/scripts/install_ctc_decoders.sh
# Out:
# Cloning into 'ctc_decoders'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 51 (delta 14), reused 40 (delta 3), pack-reused 0
# Receiving objects: 100% (51/51), 166.20 KiB | 1.20 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libboost-all-dev is already the newest version (1.74.0.3ubuntu7).
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 libwavpack1 swig4.0
# Suggested packages:
#   libsox-fmt-all swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 libwavpack1 sox swig swig4.0
# 0 upgraded, 9 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
# !wget https://www.openslr.org/resources/12/test-clean.tar.gz
# Out:
# --2024-05-02 20:15:11--  https://www.openslr.org/resources/12/test-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://openslr.elda.org/resources/12/test-clean.tar.gz [following]
# --2024-05-02 20:15:11--  https://openslr.elda.org/resources/12/test-clean.tar.gz
# Resolving openslr.elda.org (openslr.elda.org)... 141.94.109.138, 2001:41d0:203:ad8a::
# Connecting to openslr.elda.org (openslr.elda.org)|141.94.109.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 346663984 (331M) [application/x-gzip]
# Saving to: ‘test-clean.tar.gz’
#
# test-clean.tar.gz   100%[===================>] 330.60M  17.5MB/s    in 20s
#
# 2024-05-02 20:15:32 (16.8 MB/s) - ‘test-clean.tar.gz’ saved [346663984/346663984]

# %%
# !tar -xzf test-clean.tar.gz

# %%
cd /content/Squeezeformer
# Out:
# /content/Squeezeformer

# %%
# !scp -r /content/Squeezeformer/src /content/Squeezeformer/scripts

# %%
# !python scripts/create_librispeech_trans_all.py --data /content/Squeezeformer/LibriSpeech --output tsv_dir
# Out:
# processing dev-clean
# 2024-05-02 20:43:25.154300: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 20:43:25.154348: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 20:43:25.155665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 20:43:25.162774: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import gdown

# Google Drive file ID
file_id = '1qSukKHz2ltBiWU-xHGmI-P9ziPJcLcSu'

# URL for downloading the file
url = f'https://drive.google.com/uc?id={file_id}'

# Destination file path where you want to save the downloaded file
output_file = '/content/Squeezeformer/squeezeformer-M.h5'  # Adjust the path and file name as needed

# Download the file
gdown.download(url, output_file, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qSukKHz2ltBiWU-xHGmI-P9ziPJcLcSu
# To: /content/Squeezeformer/squeezeformer-M.h5
# 100%|██████████| 37.0M/37.0M [00:00<00:00, 59.1MB/s]
# '/content/Squeezeformer/squeezeformer-M.h5'

# %%
# !!pip install scikit-learn
# Out:
# ['Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)',
#  'Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)',
#  'Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)',
#  'Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)',
#  'Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)']

# %%
cd /content/Squeezeformer/examples/squeezeformer
# Out:
# /content/Squeezeformer/examples/squeezeformer

# %%
# !pip install tensorflow_io
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 103.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.36.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.36.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.36.0
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 16.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...

# %%
# !scp -r /content/Squeezeformer/src /content/Squeezeformer/examples/squeezeformer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python test.py --bs 1024 --config configs/squeezeformer-M.yml --saved /content/drive/MyDrive/squeezeformer-M.h5 \
    --dataset_path /content/Squeezeformer/tsv_dir --dataset test_clean
# Out:
# 2024-05-02 20:35:25.894149: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 20:35:25.894197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 20:35:25.895525: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 20:35:25.902559: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
